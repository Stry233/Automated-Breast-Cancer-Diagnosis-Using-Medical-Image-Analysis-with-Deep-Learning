# %%
# 导入Python的数据处理库pandas，相当于python里的excel
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np

# 导入python绘图matplotlib
import matplotlib.pyplot as plt
import json
# 使用ipython的魔法方法，将绘制出的图像直接嵌入在notebook单元格中
# %matplotlib inline

# 设置绘图大小
plt.style.use({'figure.figsize':(25,20)})

# %%
df = '../Datasets/Datasets2/BreCaHAD/groundTruth/Case_1-01.json'
with open(df) as f:
    TumorArea_list = json.load(f)
    TumorArea_list

# %%
len(TumorArea_list['tumor'])
# Out:
# 140

# %%
X = []
Y = []
for i in range(len(TumorArea_list['tumor'])):
    X.append(TumorArea_list['tumor'][i]['x'])
    Y.append(TumorArea_list['tumor'][i]['y'])

# %%
len(X)
# Out:
# 140

# %%
df = pd.DataFrame()

# %%
df.loc[:,'x'] = np.array(X)
df.loc[:,'y'] = np.array(Y)

# %%
df
# Out:
#             x         y
# 0    0.088081  0.302741
# 1    0.053979  0.259833
# 2    0.087184  0.235995
# 3    0.052184  0.225268
# 4    0.056671  0.345650
# ..        ...       ...
# 135  0.683973  0.046484
# 136  0.701024  0.044100
# 137  0.253208  0.246722
# 138  0.413847  0.700834
# 139  0.444360  0.675805
#
# [140 rows x 2 columns]

# %%
TumorArea_list['tumor']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-85b27beceb2e> in <module>
# ----> 1 TumorArea_list['tumor'].length
#
# AttributeError: 'list' object has no attribute 'length'

# %%
data_str = open(df).read()
df = pd.read_json(data_str)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-2dfa37b17dc1> in <module>
#       1 data_str = open(df).read()
# ----> 2 df = pd.read_json(data_str)
#       3 df.head()
#
# c:\python\python37\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# c:\python\python37\lib\site-packages\pandas\io\json\_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# --> 717             obj = self._get_object_parser(self.data)
#     718         self.close()
#     719         return obj
#
# ...

# %%
for TumorArea_dict in TumorArea_list:
    print(TumorArea_dict['x'], TumorArea_dict['y'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-78b41bb81c06> in <module>
#       1 for TumorArea_dict in TumorArea_list:
# ----> 2     print(TumorArea_dict['x'], TumorArea_dict['y'])
#
# TypeError: string indices must be integers
